# %% [markdown]
# We basically will:
# 1. load all the images with their label according to the name of their folder
# 2. Detect the person from each image, we skip image if no person detected
# 3. Resize images to 128x128 pixels
# 4. Extract features from each image using VGG16 model
# 5. Save images (features), and their labels (target class)

# %%
import os
import cv2
import numpy as np
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from ultralytics import YOLO
import joblib

# --- 1. Data Loading and Feature Extraction ---

dataset_dir = 'dataset'  # Replace with your dataset path
img_size = (128, 128) 

# Load YOLOv8 model 
model_yolo = YOLO('yolov8m.pt') 

def load_data(dir_path):
    """Loads images and labels from directory structure, cropping people with YOLO."""
    images = []
    labels = []
    class_names = sorted(os.listdir(dir_path))
    for i, class_name in enumerate(class_names):
        class_dir = os.path.join(dir_path, class_name)
        for img_name in os.listdir(class_dir):
            img_path = os.path.join(class_dir, img_name)

            # Load image
            img = cv2.imread(img_path)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 

            # Object Detection with YOLOv8
            results = model_yolo(img) 

            # Get bounding box coordinates of the person
            x1, y1, x2, y2 = 0, 0, 0, 0 # Initialize coordinates 
            for r in results:
                boxes = r.boxes.xyxy.tolist()  # Bounding boxes
                classes = r.boxes.cls.tolist()  # Class indices
                for box, cls in zip(boxes, classes):
                    if cls == 0:  # Assuming 'person' is class 0 
                        x1, y1, x2, y2 = map(int, box) 
                        break  # Assuming only one person per image 

            # Square Cropping
            if x1 == 0 and y1 == 0 and x2 == 0 and y2 == 0:
                print(f"Warning: Person not detected in {img_path}. Skipping image.")
                continue  # Skip to the next image

            center_x = (x1 + x2) // 2
            center_y = (y1 + y2) // 2
            crop_size = max(x2 - x1, y2 - y1)  # Size of the larger side

            crop_x1 = max(0, center_x - crop_size // 2)
            crop_y1 = max(0, center_y - crop_size // 2)
            crop_x2 = min(img.shape[1], crop_x1 + crop_size)
            crop_y2 = min(img.shape[0], crop_y1 + crop_size)

            cropped_img = img[crop_y1:crop_y2, crop_x1:crop_x2]

            # Resize cropped image to desired size
            cropped_img = cv2.resize(cropped_img, img_size)

            # --- Preprocessing for VGG16 ---
            cropped_img = image.img_to_array(cropped_img) # Convert to array
            cropped_img = preprocess_input(cropped_img) 
            images.append(cropped_img)
            labels.append(i) 
        print(f"{class_name} folder is finished \n---------------------------------------------------------------------------------------------------------------------------------------\n---------------------------------------------------------------------------------------------------------------------------------------")
    
    return np.array(images), np.array(labels), class_names

# %%
# Load data 
X, y, class_names = load_data(dataset_dir)
print(f"Number of images {len(X)}")
print(f"Number of labels {len(y)}")
# Out:
# 0: 384x640 1 person, 1 vase, 921.4ms
# Speed: 11.8ms preprocess, 921.4ms inference, 1228.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 849.2ms
# Speed: 7.5ms preprocess, 849.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 895.5ms
# Speed: 3.0ms preprocess, 895.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 752.5ms
# Speed: 3.0ms preprocess, 752.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 826.8ms
# Speed: 2.0ms preprocess, 826.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 762.5ms
# Speed: 2.0ms preprocess, 762.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 675.7ms
# Speed: 3.0ms preprocess, 675.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 638.6ms
# Speed: 4.0ms preprocess, 638.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 816.5ms
# Speed: 3.0ms preprocess, 816.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 1205.4ms
# Speed: 2.0ms preprocess, 1205.4ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2565.7ms
# Speed: 5.0ms preprocess, 2565.7ms inference, 10.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 2053.1ms
# Speed: 7.0ms preprocess, 2053.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 888.9ms
# Speed: 3.0ms preprocess, 888.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 934.3ms
# Speed: 3.0ms preprocess, 934.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 923.2ms
# Speed: 3.5ms preprocess, 923.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 869.2ms
# Speed: 2.8ms preprocess, 869.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 817.0ms
# Speed: 3.0ms preprocess, 817.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 829.5ms
# Speed: 3.6ms preprocess, 829.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 844.6ms
# Speed: 4.0ms preprocess, 844.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 846.6ms
# Speed: 4.4ms preprocess, 846.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 826.9ms
# Speed: 2.2ms preprocess, 826.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 848.5ms
# Speed: 3.0ms preprocess, 848.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 826.0ms
# Speed: 2.0ms preprocess, 826.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 820.2ms
# Speed: 2.0ms preprocess, 820.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 871.8ms
# Speed: 3.0ms preprocess, 871.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 862.0ms
# Speed: 3.0ms preprocess, 862.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 803.0ms
# Speed: 2.0ms preprocess, 803.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 889.3ms
# Speed: 2.0ms preprocess, 889.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 902.4ms
# Speed: 4.0ms preprocess, 902.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 968.1ms
# Speed: 3.0ms preprocess, 968.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 893.7ms
# Speed: 2.6ms preprocess, 893.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 841.4ms
# Speed: 3.5ms preprocess, 841.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 862.1ms
# Speed: 2.0ms preprocess, 862.1ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 874.1ms
# Speed: 2.6ms preprocess, 874.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 868.7ms
# Speed: 3.0ms preprocess, 868.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 874.0ms
# Speed: 2.6ms preprocess, 874.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 866.8ms
# Speed: 2.0ms preprocess, 866.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 856.9ms
# Speed: 3.0ms preprocess, 856.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 860.7ms
# Speed: 3.0ms preprocess, 860.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 905.7ms
# Speed: 2.5ms preprocess, 905.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 838.9ms
# Speed: 2.1ms preprocess, 838.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 891.0ms
# Speed: 2.1ms preprocess, 891.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 860.2ms
# Speed: 2.5ms preprocess, 860.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 853.0ms
# Speed: 2.6ms preprocess, 853.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 826.6ms
# Speed: 2.0ms preprocess, 826.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 809.4ms
# Speed: 2.6ms preprocess, 809.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 825.4ms
# Speed: 5.3ms preprocess, 825.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 834.2ms
# Speed: 2.0ms preprocess, 834.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 850.3ms
# Speed: 3.0ms preprocess, 850.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 872.7ms
# Speed: 2.0ms preprocess, 872.7ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 830.8ms
# Speed: 2.6ms preprocess, 830.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 767.6ms
# Speed: 2.1ms preprocess, 767.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 824.7ms
# Speed: 2.4ms preprocess, 824.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 827.1ms
# Speed: 3.0ms preprocess, 827.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 830.8ms
# Speed: 3.0ms preprocess, 830.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 875.5ms
# Speed: 4.0ms preprocess, 875.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 831.7ms
# Speed: 4.5ms preprocess, 831.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 861.6ms
# Speed: 2.6ms preprocess, 861.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 849.6ms
# Speed: 2.0ms preprocess, 849.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 829.6ms
# Speed: 2.2ms preprocess, 829.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 852.0ms
# Speed: 2.9ms preprocess, 852.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 890.5ms
# Speed: 3.0ms preprocess, 890.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 884.3ms
# Speed: 3.0ms preprocess, 884.3ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 855.4ms
# Speed: 1.9ms preprocess, 855.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 884.8ms
# Speed: 2.0ms preprocess, 884.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 844.1ms
# Speed: 3.0ms preprocess, 844.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 848.9ms
# Speed: 2.0ms preprocess, 848.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 821.6ms
# Speed: 2.0ms preprocess, 821.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 831.9ms
# Speed: 2.0ms preprocess, 831.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 891.5ms
# Speed: 2.0ms preprocess, 891.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 833.1ms
# Speed: 2.5ms preprocess, 833.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 858.8ms
# Speed: 2.0ms preprocess, 858.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 872.0ms
# Speed: 3.5ms preprocess, 872.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 904.5ms
# Speed: 2.0ms preprocess, 904.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 850.7ms
# Speed: 3.5ms preprocess, 850.7ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 862.6ms
# Speed: 3.5ms preprocess, 862.6ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 901.3ms
# Speed: 1.9ms preprocess, 901.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 853.7ms
# Speed: 2.6ms preprocess, 853.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 866.3ms
# Speed: 3.5ms preprocess, 866.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 826.7ms
# Speed: 1.5ms preprocess, 826.7ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 836.7ms
# Speed: 2.7ms preprocess, 836.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 852.5ms
# Speed: 3.0ms preprocess, 852.5ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 878.4ms
# Speed: 4.3ms preprocess, 878.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 828.4ms
# Speed: 2.0ms preprocess, 828.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 840.5ms
# Speed: 3.5ms preprocess, 840.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 813.3ms
# Speed: 3.0ms preprocess, 813.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 808.9ms
# Speed: 3.0ms preprocess, 808.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 894.3ms
# Speed: 4.0ms preprocess, 894.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 881.9ms
# Speed: 2.0ms preprocess, 881.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 839.3ms
# Speed: 1.9ms preprocess, 839.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 839.8ms
# Speed: 2.5ms preprocess, 839.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 876.7ms
# Speed: 3.0ms preprocess, 876.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 822.3ms
# Speed: 3.0ms preprocess, 822.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 823.2ms
# Speed: 3.0ms preprocess, 823.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 836.0ms
# Speed: 2.0ms preprocess, 836.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 888.4ms
# Speed: 3.0ms preprocess, 888.4ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 852.3ms
# Speed: 3.0ms preprocess, 852.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 859.9ms
# Speed: 2.2ms preprocess, 859.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 906.7ms
# Speed: 3.0ms preprocess, 906.7ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 859.1ms
# Speed: 2.2ms preprocess, 859.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 875.7ms
# Speed: 1.9ms preprocess, 875.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 853.5ms
# Speed: 3.0ms preprocess, 853.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 881.6ms
# Speed: 2.5ms preprocess, 881.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 856.0ms
# Speed: 3.0ms preprocess, 856.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 878.0ms
# Speed: 2.5ms preprocess, 878.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 856.4ms
# Speed: 2.8ms preprocess, 856.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 792.4ms
# Speed: 3.1ms preprocess, 792.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 805.1ms
# Speed: 2.5ms preprocess, 805.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 813.8ms
# Speed: 3.0ms preprocess, 813.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 904.0ms
# Speed: 2.0ms preprocess, 904.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 865.5ms
# Speed: 2.7ms preprocess, 865.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 841.5ms
# Speed: 2.2ms preprocess, 841.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 859.6ms
# Speed: 2.5ms preprocess, 859.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 864.0ms
# Speed: 2.5ms preprocess, 864.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 898.5ms
# Speed: 3.1ms preprocess, 898.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 862.3ms
# Speed: 2.9ms preprocess, 862.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 890.3ms
# Speed: 3.0ms preprocess, 890.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 881.5ms
# Speed: 2.0ms preprocess, 881.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 872.7ms
# Speed: 2.1ms preprocess, 872.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 910.4ms
# Speed: 2.0ms preprocess, 910.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 770.1ms
# Speed: 2.0ms preprocess, 770.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 841.0ms
# Speed: 2.0ms preprocess, 841.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 885.1ms
# Speed: 3.0ms preprocess, 885.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 820.4ms
# Speed: 2.2ms preprocess, 820.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 890.7ms
# Speed: 2.5ms preprocess, 890.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 850.6ms
# Speed: 2.5ms preprocess, 850.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 873.3ms
# Speed: 2.0ms preprocess, 873.3ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 841.4ms
# Speed: 3.0ms preprocess, 841.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 840.1ms
# Speed: 2.0ms preprocess, 840.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 902.0ms
# Speed: 4.0ms preprocess, 902.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 797.2ms
# Speed: 3.4ms preprocess, 797.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 887.8ms
# Speed: 3.1ms preprocess, 887.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 828.6ms
# Speed: 3.5ms preprocess, 828.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 784.8ms
# Speed: 2.5ms preprocess, 784.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 813.7ms
# Speed: 2.0ms preprocess, 813.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 839.4ms
# Speed: 2.7ms preprocess, 839.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 855.1ms
# Speed: 3.0ms preprocess, 855.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 836.4ms
# Speed: 3.0ms preprocess, 836.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 898.8ms
# Speed: 2.4ms preprocess, 898.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 842.1ms
# Speed: 3.0ms preprocess, 842.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 901.9ms
# Speed: 2.0ms preprocess, 901.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 919.6ms
# Speed: 1.5ms preprocess, 919.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 855.1ms
# Speed: 4.0ms preprocess, 855.1ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 891.5ms
# Speed: 4.0ms preprocess, 891.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 842.0ms
# Speed: 2.0ms preprocess, 842.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 861.7ms
# Speed: 3.0ms preprocess, 861.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 858.4ms
# Speed: 2.5ms preprocess, 858.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 885.4ms
# Speed: 3.1ms preprocess, 885.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 888.1ms
# Speed: 1.9ms preprocess, 888.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 879.3ms
# Speed: 3.0ms preprocess, 879.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 895.1ms
# Speed: 2.5ms preprocess, 895.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 886.3ms
# Speed: 3.0ms preprocess, 886.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 836.8ms
# Speed: 2.6ms preprocess, 836.8ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 869.8ms
# Speed: 2.0ms preprocess, 869.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 821.2ms
# Speed: 2.0ms preprocess, 821.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 760.4ms
# Speed: 2.0ms preprocess, 760.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 835.2ms
# Speed: 2.0ms preprocess, 835.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 869.1ms
# Speed: 3.5ms preprocess, 869.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 874.0ms
# Speed: 3.0ms preprocess, 874.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 843.0ms
# Speed: 2.0ms preprocess, 843.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 799.2ms
# Speed: 2.2ms preprocess, 799.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 798.4ms
# Speed: 2.0ms preprocess, 798.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 800.1ms
# Speed: 2.0ms preprocess, 800.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 822.3ms
# Speed: 2.5ms preprocess, 822.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 908.0ms
# Speed: 2.0ms preprocess, 908.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 888.3ms
# Speed: 3.0ms preprocess, 888.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 847.3ms
# Speed: 2.7ms preprocess, 847.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 902.5ms
# Speed: 3.5ms preprocess, 902.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 871.0ms
# Speed: 6.0ms preprocess, 871.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 842.8ms
# Speed: 2.5ms preprocess, 842.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 843.9ms
# Speed: 2.0ms preprocess, 843.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 848.3ms
# Speed: 2.5ms preprocess, 848.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 888.5ms
# Speed: 2.5ms preprocess, 888.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 882.8ms
# Speed: 2.0ms preprocess, 882.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 924.2ms
# Speed: 3.5ms preprocess, 924.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 859.8ms
# Speed: 2.5ms preprocess, 859.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 874.6ms
# Speed: 2.0ms preprocess, 874.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 848.1ms
# Speed: 3.0ms preprocess, 848.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 888.8ms
# Speed: 2.0ms preprocess, 888.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 889.0ms
# Speed: 3.0ms preprocess, 889.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 849.7ms
# Speed: 2.0ms preprocess, 849.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 852.5ms
# Speed: 5.0ms preprocess, 852.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 839.1ms
# Speed: 3.0ms preprocess, 839.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 898.8ms
# Speed: 2.6ms preprocess, 898.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 867.2ms
# Speed: 3.0ms preprocess, 867.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 879.3ms
# Speed: 3.0ms preprocess, 879.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 832.1ms
# Speed: 3.0ms preprocess, 832.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 807.9ms
# Speed: 2.0ms preprocess, 807.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 820.3ms
# Speed: 2.0ms preprocess, 820.3ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 794.6ms
# Speed: 2.7ms preprocess, 794.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 807.4ms
# Speed: 3.0ms preprocess, 807.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 882.8ms
# Speed: 3.6ms preprocess, 882.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 848.3ms
# Speed: 2.0ms preprocess, 848.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 901.0ms
# Speed: 2.0ms preprocess, 901.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 891.7ms
# Speed: 2.1ms preprocess, 891.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 887.2ms
# Speed: 2.0ms preprocess, 887.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 866.0ms
# Speed: 2.5ms preprocess, 866.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 818.9ms
# Speed: 3.1ms preprocess, 818.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 897.4ms
# Speed: 3.5ms preprocess, 897.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 885.7ms
# Speed: 3.1ms preprocess, 885.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 920.1ms
# Speed: 1.9ms preprocess, 920.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 850.2ms
# Speed: 2.0ms preprocess, 850.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 891.0ms
# Speed: 2.9ms preprocess, 891.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 860.9ms
# Speed: 2.5ms preprocess, 860.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 856.2ms
# Speed: 4.2ms preprocess, 856.2ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 856.8ms
# Speed: 3.0ms preprocess, 856.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 866.4ms
# Speed: 2.4ms preprocess, 866.4ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 921.8ms
# Speed: 3.3ms preprocess, 921.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 876.8ms
# Speed: 2.0ms preprocess, 876.8ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 864.7ms
# Speed: 3.0ms preprocess, 864.7ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 910.0ms
# Speed: 3.0ms preprocess, 910.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 887.6ms
# Speed: 2.0ms preprocess, 887.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 860.9ms
# Speed: 3.0ms preprocess, 860.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 804.8ms
# Speed: 2.0ms preprocess, 804.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 800.2ms
# Speed: 3.0ms preprocess, 800.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 793.6ms
# Speed: 3.0ms preprocess, 793.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 861.5ms
# Speed: 2.5ms preprocess, 861.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 892.0ms
# Speed: 2.9ms preprocess, 892.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 915.9ms
# Speed: 2.5ms preprocess, 915.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 876.1ms
# Speed: 2.0ms preprocess, 876.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 878.7ms
# Speed: 2.0ms preprocess, 878.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 928.4ms
# Speed: 2.0ms preprocess, 928.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 872.6ms
# Speed: 3.0ms preprocess, 872.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 829.1ms
# Speed: 3.0ms preprocess, 829.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 790.1ms
# Speed: 3.0ms preprocess, 790.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 849.9ms
# Speed: 3.0ms preprocess, 849.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 869.4ms
# Speed: 2.0ms preprocess, 869.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 898.7ms
# Speed: 4.2ms preprocess, 898.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 874.1ms
# Speed: 2.0ms preprocess, 874.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 908.8ms
# Speed: 3.0ms preprocess, 908.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 912.0ms
# Speed: 3.0ms preprocess, 912.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 902.1ms
# Speed: 4.0ms preprocess, 902.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 891.6ms
# Speed: 3.0ms preprocess, 891.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 928.0ms
# Speed: 3.0ms preprocess, 928.0ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 849.2ms
# Speed: 2.0ms preprocess, 849.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 865.3ms
# Speed: 2.0ms preprocess, 865.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 860.4ms
# Speed: 3.0ms preprocess, 860.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 907.0ms
# Speed: 3.5ms preprocess, 907.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 877.0ms
# Speed: 1.9ms preprocess, 877.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 822.1ms
# Speed: 2.5ms preprocess, 822.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 880.7ms
# Speed: 3.0ms preprocess, 880.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 828.9ms
# Speed: 3.1ms preprocess, 828.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 897.9ms
# Speed: 3.2ms preprocess, 897.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 878.4ms
# Speed: 3.0ms preprocess, 878.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 870.9ms
# Speed: 2.0ms preprocess, 870.9ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 882.9ms
# Speed: 1.7ms preprocess, 882.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 838.6ms
# Speed: 2.0ms preprocess, 838.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 849.8ms
# Speed: 2.5ms preprocess, 849.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 899.8ms
# Speed: 2.0ms preprocess, 899.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 891.2ms
# Speed: 3.0ms preprocess, 891.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 867.2ms
# Speed: 2.1ms preprocess, 867.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 923.9ms
# Speed: 2.8ms preprocess, 923.9ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 910.5ms
# Speed: 3.0ms preprocess, 910.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 870.1ms
# Speed: 2.0ms preprocess, 870.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 884.6ms
# Speed: 3.4ms preprocess, 884.6ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 894.8ms
# Speed: 2.6ms preprocess, 894.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 870.5ms
# Speed: 1.9ms preprocess, 870.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 839.5ms
# Speed: 2.0ms preprocess, 839.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 841.8ms
# Speed: 3.0ms preprocess, 841.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 878.7ms
# Speed: 4.1ms preprocess, 878.7ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 855.1ms
# Speed: 2.0ms preprocess, 855.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 904.8ms
# Speed: 3.0ms preprocess, 904.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 873.3ms
# Speed: 3.3ms preprocess, 873.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 814.2ms
# Speed: 4.0ms preprocess, 814.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 829.9ms
# Speed: 2.9ms preprocess, 829.9ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 822.6ms
# Speed: 2.5ms preprocess, 822.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 832.0ms
# Speed: 3.5ms preprocess, 832.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 824.6ms
# Speed: 3.0ms preprocess, 824.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 864.5ms
# Speed: 3.0ms preprocess, 864.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 852.8ms
# Speed: 3.0ms preprocess, 852.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 861.2ms
# Speed: 4.1ms preprocess, 861.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 869.4ms
# Speed: 3.4ms preprocess, 869.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 840.5ms
# Speed: 3.6ms preprocess, 840.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 861.9ms
# Speed: 2.2ms preprocess, 861.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 900.2ms
# Speed: 2.0ms preprocess, 900.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 904.6ms
# Speed: 3.0ms preprocess, 904.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 871.8ms
# Speed: 3.0ms preprocess, 871.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 931.8ms
# Speed: 2.1ms preprocess, 931.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 929.1ms
# Speed: 2.5ms preprocess, 929.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 851.2ms
# Speed: 3.1ms preprocess, 851.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 923.3ms
# Speed: 1.9ms preprocess, 923.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 869.4ms
# Speed: 2.0ms preprocess, 869.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 884.4ms
# Speed: 3.5ms preprocess, 884.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 876.4ms
# Speed: 3.0ms preprocess, 876.4ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 916.0ms
# Speed: 2.0ms preprocess, 916.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 833.2ms
# Speed: 2.0ms preprocess, 833.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 864.8ms
# Speed: 2.0ms preprocess, 864.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 911.5ms
# Speed: 3.0ms preprocess, 911.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 899.8ms
# Speed: 2.0ms preprocess, 899.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 855.3ms
# Speed: 2.0ms preprocess, 855.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 889.8ms
# Speed: 3.3ms preprocess, 889.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 798.0ms
# Speed: 2.5ms preprocess, 798.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 795.0ms
# Speed: 3.4ms preprocess, 795.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 826.9ms
# Speed: 3.0ms preprocess, 826.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 853.8ms
# Speed: 3.0ms preprocess, 853.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 827.2ms
# Speed: 4.0ms preprocess, 827.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 888.5ms
# Speed: 3.7ms preprocess, 888.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 903.4ms
# Speed: 3.8ms preprocess, 903.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 857.4ms
# Speed: 3.5ms preprocess, 857.4ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 914.8ms
# Speed: 2.0ms preprocess, 914.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 867.4ms
# Speed: 2.0ms preprocess, 867.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 887.8ms
# Speed: 3.0ms preprocess, 887.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 864.3ms
# Speed: 3.0ms preprocess, 864.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 860.6ms
# Speed: 4.1ms preprocess, 860.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 896.1ms
# Speed: 3.0ms preprocess, 896.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 856.2ms
# Speed: 3.5ms preprocess, 856.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 938.9ms
# Speed: 2.1ms preprocess, 938.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 892.2ms
# Speed: 3.0ms preprocess, 892.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 896.6ms
# Speed: 2.6ms preprocess, 896.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 841.9ms
# Speed: 3.0ms preprocess, 841.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 937.8ms
# Speed: 3.1ms preprocess, 937.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 841.2ms
# Speed: 2.0ms preprocess, 841.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 790.5ms
# Speed: 3.0ms preprocess, 790.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 846.4ms
# Speed: 2.0ms preprocess, 846.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 910.1ms
# Speed: 4.0ms preprocess, 910.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 847.4ms
# Speed: 2.0ms preprocess, 847.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 891.6ms
# Speed: 2.6ms preprocess, 891.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 860.8ms
# Speed: 4.5ms preprocess, 860.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 899.2ms
# Speed: 3.0ms preprocess, 899.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 vase, 866.8ms
# Speed: 3.0ms preprocess, 866.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 879.0ms
# Speed: 2.0ms preprocess, 879.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 847.2ms
# Speed: 2.0ms preprocess, 847.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 855.2ms
# Speed: 3.5ms preprocess, 855.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 848.2ms
# Speed: 2.0ms preprocess, 848.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 820.2ms
# Speed: 2.0ms preprocess, 820.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 818.4ms
# Speed: 2.3ms preprocess, 818.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 801.5ms
# Speed: 3.5ms preprocess, 801.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 852.4ms
# Speed: 2.0ms preprocess, 852.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 870.2ms
# Speed: 2.6ms preprocess, 870.2ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 850.9ms
# Speed: 3.8ms preprocess, 850.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 896.3ms
# Speed: 2.0ms preprocess, 896.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 889.3ms
# Speed: 2.0ms preprocess, 889.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 867.9ms
# Speed: 3.0ms preprocess, 867.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 886.4ms
# Speed: 3.0ms preprocess, 886.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 893.9ms
# Speed: 2.0ms preprocess, 893.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 876.5ms
# Speed: 3.5ms preprocess, 876.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 892.2ms
# Speed: 2.2ms preprocess, 892.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 912.3ms
# Speed: 3.0ms preprocess, 912.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 863.9ms
# Speed: 2.6ms preprocess, 863.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 853.1ms
# Speed: 2.0ms preprocess, 853.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 855.8ms
# Speed: 4.0ms preprocess, 855.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 867.9ms
# Speed: 2.0ms preprocess, 867.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 923.7ms
# Speed: 4.6ms preprocess, 923.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 890.0ms
# Speed: 2.3ms preprocess, 890.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 902.1ms
# Speed: 3.0ms preprocess, 902.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 852.7ms
# Speed: 3.0ms preprocess, 852.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 911.4ms
# Speed: 2.0ms preprocess, 911.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 858.2ms
# Speed: 3.0ms preprocess, 858.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bird, 1 vase, 887.2ms
# Speed: 3.0ms preprocess, 887.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 777.7ms
# Speed: 2.0ms preprocess, 777.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 790.4ms
# Speed: 3.5ms preprocess, 790.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 830.2ms
# Speed: 2.5ms preprocess, 830.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 vase, 814.2ms
# Speed: 2.0ms preprocess, 814.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
#
# 0: 480x640 1 person, 1 bottle, 978.4ms
# Speed: 3.0ms preprocess, 978.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 949.8ms
# Speed: 2.0ms preprocess, 949.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 1005.8ms
# Speed: 2.5ms preprocess, 1005.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1010.8ms
# Speed: 2.0ms preprocess, 1010.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1028.0ms
# Speed: 3.1ms preprocess, 1028.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 2 beds, 975.9ms
# Speed: 4.0ms preprocess, 975.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 2 beds, 981.5ms
# Speed: 2.1ms preprocess, 981.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 bed, 1 toothbrush, 976.1ms
# Speed: 2.5ms preprocess, 976.1ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1003.7ms
# Speed: 2.2ms preprocess, 1003.7ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 toothbrush, 978.9ms
# Speed: 4.0ms preprocess, 978.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 931.9ms
# Speed: 2.0ms preprocess, 931.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 963.7ms
# Speed: 2.1ms preprocess, 963.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 967.1ms
# Speed: 2.0ms preprocess, 967.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1018.6ms
# Speed: 2.0ms preprocess, 1018.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1021.1ms
# Speed: 9.0ms preprocess, 1021.1ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 981.0ms
# Speed: 3.0ms preprocess, 981.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1008.7ms
# Speed: 3.0ms preprocess, 1008.7ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1056.6ms
# Speed: 2.0ms preprocess, 1056.6ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1056.9ms
# Speed: 4.0ms preprocess, 1056.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 987.1ms
# Speed: 4.0ms preprocess, 987.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 988.6ms
# Speed: 3.1ms preprocess, 988.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 995.4ms
# Speed: 3.0ms preprocess, 995.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 954.0ms
# Speed: 3.0ms preprocess, 954.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1047.0ms
# Speed: 2.1ms preprocess, 1047.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1031.9ms
# Speed: 6.5ms preprocess, 1031.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1040.7ms
# Speed: 2.0ms preprocess, 1040.7ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1009.3ms
# Speed: 7.0ms preprocess, 1009.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 bed, 1039.8ms
# Speed: 3.0ms preprocess, 1039.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 bed, 1013.7ms
# Speed: 2.0ms preprocess, 1013.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 bed, 1014.5ms
# Speed: 3.0ms preprocess, 1014.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 bed, 1072.3ms
# Speed: 3.0ms preprocess, 1072.3ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 toothbrush, 944.9ms
# Speed: 3.0ms preprocess, 944.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 943.9ms
# Speed: 2.0ms preprocess, 943.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 994.7ms
# Speed: 1.9ms preprocess, 994.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 959.4ms
# Speed: 2.0ms preprocess, 959.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 969.5ms
# Speed: 2.0ms preprocess, 969.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 952.7ms
# Speed: 3.1ms preprocess, 952.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 950.7ms
# Speed: 2.0ms preprocess, 950.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 959.2ms
# Speed: 2.1ms preprocess, 959.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1039.6ms
# Speed: 3.0ms preprocess, 1039.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 960.2ms
# Speed: 5.0ms preprocess, 960.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 941.3ms
# Speed: 3.0ms preprocess, 941.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 bed, 1016.0ms
# Speed: 3.0ms preprocess, 1016.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 2 beds, 994.8ms
# Speed: 3.0ms preprocess, 994.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 bed, 1012.7ms
# Speed: 2.0ms preprocess, 1012.7ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 1 bed, 1029.2ms
# Speed: 3.0ms preprocess, 1029.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 1050.2ms
# Speed: 4.0ms preprocess, 1050.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 bed, 982.1ms
# Speed: 2.0ms preprocess, 982.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 1028.2ms
# Speed: 2.0ms preprocess, 1028.2ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1003.9ms
# Speed: 4.9ms preprocess, 1003.9ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1250.7ms
# Speed: 2.0ms preprocess, 1250.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1246.0ms
# Speed: 4.0ms preprocess, 1246.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1334.3ms
# Speed: 5.0ms preprocess, 1334.3ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1273.9ms
# Speed: 5.0ms preprocess, 1273.9ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1394.5ms
# Speed: 5.0ms preprocess, 1394.5ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1060.7ms
# Speed: 6.3ms preprocess, 1060.7ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 bed, 1040.8ms
# Speed: 7.0ms preprocess, 1040.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1033.3ms
# Speed: 3.0ms preprocess, 1033.3ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 bed, 1140.7ms
# Speed: 6.0ms preprocess, 1140.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 bed, 1069.6ms
# Speed: 4.0ms preprocess, 1069.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1042.4ms
# Speed: 3.1ms preprocess, 1042.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1067.7ms
# Speed: 6.0ms preprocess, 1067.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 bed, 1112.7ms
# Speed: 3.2ms preprocess, 1112.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 997.5ms
# Speed: 2.0ms preprocess, 997.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1062.3ms
# Speed: 4.0ms preprocess, 1062.3ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1037.9ms
# Speed: 2.0ms preprocess, 1037.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 997.2ms
# Speed: 3.6ms preprocess, 997.2ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 bed, 1049.8ms
# Speed: 2.1ms preprocess, 1049.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 1091.7ms
# Speed: 4.0ms preprocess, 1091.7ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 1027.9ms
# Speed: 2.9ms preprocess, 1027.9ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 1011.3ms
# Speed: 4.0ms preprocess, 1011.3ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 bed, 1027.1ms
# Speed: 2.5ms preprocess, 1027.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 bed, 1009.2ms
# Speed: 3.0ms preprocess, 1009.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 1 toothbrush, 1029.0ms
# Speed: 2.0ms preprocess, 1029.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 1 bed, 1 toothbrush, 1069.3ms
# Speed: 2.0ms preprocess, 1069.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 bed, 1100.2ms
# Speed: 6.0ms preprocess, 1100.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1039.3ms
# Speed: 2.9ms preprocess, 1039.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1022.2ms
# Speed: 2.0ms preprocess, 1022.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1033.0ms
# Speed: 2.0ms preprocess, 1033.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 997.3ms
# Speed: 3.0ms preprocess, 997.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1105.5ms
# Speed: 4.0ms preprocess, 1105.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1045.9ms
# Speed: 2.0ms preprocess, 1045.9ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1082.8ms
# Speed: 2.1ms preprocess, 1082.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1098.3ms
# Speed: 3.1ms preprocess, 1098.3ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1087.9ms
# Speed: 5.0ms preprocess, 1087.9ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1086.7ms
# Speed: 2.9ms preprocess, 1086.7ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 999.1ms
# Speed: 6.0ms preprocess, 999.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1054.3ms
# Speed: 3.0ms preprocess, 1054.3ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1036.0ms
# Speed: 3.2ms preprocess, 1036.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 965.8ms
# Speed: 6.0ms preprocess, 965.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 998.7ms
# Speed: 2.0ms preprocess, 998.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1022.4ms
# Speed: 2.0ms preprocess, 1022.4ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1012.5ms
# Speed: 2.0ms preprocess, 1012.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1019.3ms
# Speed: 3.0ms preprocess, 1019.3ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1096.2ms
# Speed: 3.0ms preprocess, 1096.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1024.4ms
# Speed: 2.1ms preprocess, 1024.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1049.7ms
# Speed: 10.0ms preprocess, 1049.7ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1064.0ms
# Speed: 3.0ms preprocess, 1064.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1058.5ms
# Speed: 3.0ms preprocess, 1058.5ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 toothbrush, 1032.2ms
# Speed: 5.0ms preprocess, 1032.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1035.3ms
# Speed: 5.0ms preprocess, 1035.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1024.1ms
# Speed: 3.0ms preprocess, 1024.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1114.2ms
# Speed: 4.0ms preprocess, 1114.2ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1032.0ms
# Speed: 2.0ms preprocess, 1032.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1153.6ms
# Speed: 2.0ms preprocess, 1153.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1150.3ms
# Speed: 3.0ms preprocess, 1150.3ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1081.5ms
# Speed: 2.0ms preprocess, 1081.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 toothbrush, 1043.1ms
# Speed: 3.0ms preprocess, 1043.1ms inference, 13.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1042.8ms
# Speed: 2.0ms preprocess, 1042.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1044.6ms
# Speed: 6.0ms preprocess, 1044.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# writing_reading folder is finished
# ---------------------------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------------------------------
# Number of images 8083
# Number of labels 8083

# %% [markdown]
# Let's create our feature extracting VGG16 model:

# %%
# Load VGG16 model (without top)
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(img_size[0], img_size[1], 3)) 

# Extract features
features = base_model.predict(X) 
features = features.reshape(features.shape[0], -1)
# Out:
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 232s 916ms/step

# %% [markdown]
# Since some classes have more than other classes, we might want to balance all the classes so there is no bias towards one over another!

# %%
from imblearn.combine import SMOTEENN

smote_enn = SMOTEENN(random_state=42)
X_balanced, y_balanced = smote_enn.fit_resample(X, y)

# %% [markdown]
# Let's split our data into training and testing set:

# %%
# --- 2. Data Splitting and Scaling ---

X_train, X_test, y_train, y_test = train_test_split(X_balanced, y_balanced, test_size=0.3, shuffle=True,random_state=42)

# scaler = StandardScaler()
# X_train = scaler.fit_transform(X_train)
# X_test = scaler.transform(X_test)

# %%
print(f"{X_train.shape}, {X_test.shape}")
# Out:
# (14004, 8192), (6002, 8192)

# %% [markdown]
# We tried to scale data but apparently it doesn't make any difference!

# %% [markdown]
# ### SVM

# %%
# --- 3. Model Training (SVM) ---

model = SVC(kernel='rbf', C=1.0, random_state=42) 
model.fit(X_train, y_train)

# --- 4. Model Evaluation ---

y_pred = model.predict(X_test)
print('Accuracy:', accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred, target_names=class_names)) 
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 1.0
#                   precision    recall  f1-score   support
#
#       distracted       1.00      1.00      1.00       837
#          fatigue       1.00      1.00      1.00       853
#          focused       1.00      1.00      1.00       887
#       raise_hand       1.00      1.00      1.00       848
#         sleeping       1.00      1.00      1.00       892
# using_smartphone       1.00      1.00      1.00       865
#  writing_reading       1.00      1.00      1.00       820
#
#         accuracy                           1.00      6002
#        macro avg       1.00      1.00      1.00      6002
#     weighted avg       1.00      1.00      1.00      6002
#
# [[837   0   0   0   0   0   0]
#  [  0 853   0   0   0   0   0]
#  [  0   0 887   0   0   0   0]
#  [  0   0   0 848   0   0   0]
#  [  0   0   0   0 892   0   0]
#  [  0   0   0   0   0 865   0]
#  [  0   0   0   0   0   0 820]]

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_model = KNeighborsClassifier(n_neighbors=5)  # Choose a value for k
knn_model.fit(X_train, y_train) 

# ... (Evaluate the model)
y_pred_knn = knn_model.predict(X_test)
print('Accuracy:', accuracy_score(y_test, y_pred_knn))
print(classification_report(y_test, y_pred_knn, target_names=class_names)) 
print(confusion_matrix(y_test, y_pred_knn))
# Out:
# Accuracy: 1.0
#                   precision    recall  f1-score   support
#
#       distracted       1.00      1.00      1.00       837
#          fatigue       1.00      1.00      1.00       853
#          focused       1.00      1.00      1.00       887
#       raise_hand       1.00      1.00      1.00       848
#         sleeping       1.00      1.00      1.00       892
# using_smartphone       1.00      1.00      1.00       865
#  writing_reading       1.00      1.00      1.00       820
#
#         accuracy                           1.00      6002
#        macro avg       1.00      1.00      1.00      6002
#     weighted avg       1.00      1.00      1.00      6002
#
# [[837   0   0   0   0   0   0]
#  [  0 853   0   0   0   0   0]
#  [  0   0 887   0   0   0   0]
#  [  0   0   0 848   0   0   0]
#  [  0   0   0   0 892   0   0]
#  [  0   0   0   0   0 865   0]
#  [  0   0   0   0   0   0 820]]

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(X_train, y_train)
# ... (Evaluate the model)
y_pred_dt = dt_model.predict(X_test)
print('Accuracy:', accuracy_score(y_test, y_pred_dt))
print(classification_report(y_test, y_pred_dt, target_names=class_names)) 
print(confusion_matrix(y_test, y_pred_dt))
# Out:
# Accuracy: 0.9968343885371543
#                   precision    recall  f1-score   support
#
#       distracted       1.00      1.00      1.00       837
#          fatigue       1.00      1.00      1.00       853
#          focused       0.99      1.00      0.99       887
#       raise_hand       1.00      1.00      1.00       848
#         sleeping       1.00      0.99      1.00       892
# using_smartphone       1.00      1.00      1.00       865
#  writing_reading       1.00      1.00      1.00       820
#
#         accuracy                           1.00      6002
#        macro avg       1.00      1.00      1.00      6002
#     weighted avg       1.00      1.00      1.00      6002
#
# [[834   0   3   0   0   0   0]
#  [  0 851   0   1   0   1   0]
#  [  1   0 885   0   0   0   1]
#  [  0   0   1 846   0   0   1]
#  [  0   4   2   0 885   1   0]
#  [  2   0   0   0   0 863   0]
#  [  0   0   1   0   0   0 819]]

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)  # Adjust n_estimators as needed
rf_model.fit(X_train, y_train)
# ... (Evaluate the model)
y_pred_rf = rf_model.predict(X_test)
print('Accuracy:', accuracy_score(y_test, y_pred_rf))
print(classification_report(y_test, y_pred_rf, target_names=class_names)) 
print(confusion_matrix(y_test, y_pred_rf))
# Out:
# Accuracy: 1.0
#                   precision    recall  f1-score   support
#
#       distracted       1.00      1.00      1.00       837
#          fatigue       1.00      1.00      1.00       853
#          focused       1.00      1.00      1.00       887
#       raise_hand       1.00      1.00      1.00       848
#         sleeping       1.00      1.00      1.00       892
# using_smartphone       1.00      1.00      1.00       865
#  writing_reading       1.00      1.00      1.00       820
#
#         accuracy                           1.00      6002
#        macro avg       1.00      1.00      1.00      6002
#     weighted avg       1.00      1.00      1.00      6002
#
# [[837   0   0   0   0   0   0]
#  [  0 853   0   0   0   0   0]
#  [  0   0 887   0   0   0   0]
#  [  0   0   0 848   0   0   0]
#  [  0   0   0   0 892   0   0]
#  [  0   0   0   0   0 865   0]
#  [  0   0   0   0   0   0 820]]

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr_model = LogisticRegression(random_state=42) 
lr_model.fit(X_train, y_train)
# ... (Evaluate the model)
y_pred_lr = lr_model.predict(X_test)
print('Accuracy:', accuracy_score(y_test, y_pred_lr))
print(classification_report(y_test, y_pred_lr, target_names=class_names)) 
print(confusion_matrix(y_test, y_pred_lr))
# Out:
# c:\Users\abdel\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy: 1.0
#                   precision    recall  f1-score   support
#
#       distracted       1.00      1.00      1.00       837
#          fatigue       1.00      1.00      1.00       853
#          focused       1.00      1.00      1.00       887
#       raise_hand       1.00      1.00      1.00       848
#         sleeping       1.00      1.00      1.00       892
# using_smartphone       1.00      1.00      1.00       865
#  writing_reading       1.00      1.00      1.00       820
#
#         accuracy                           1.00      6002
#        macro avg       1.00      1.00      1.00      6002
#     weighted avg       1.00      1.00      1.00      6002
#
# [[837   0   0   0   0   0   0]
#  [  0 853   0   0   0   0   0]
#  [  0   0 887   0   0   0   0]
#  [  0   0   0 848   0   0   0]
#  [  0   0   0   0 892   0   0]
#  [  0   0   0   0   0 865   0]
#  [  0   0   0   0   0   0 820]]

# %% [markdown]
# ### Evaluate on unseen data:

# %%
# --- 5. Prediction on a New Image ---


base_model = VGG16(weights='imagenet', include_top=False, input_shape=(img_size[0], img_size[1], 3)) 
    
def predict_image(image_path, model, class_names):
    """Predicts the class of a single image."""
    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 

    # Object Detection with YOLOv8
    results = model_yolo(img) 

     # Get bounding box coordinates of the person
    x1, y1, x2, y2 = 0, 0, 0, 0 # Initialize coordinates 
    for r in results:
        boxes = r.boxes.xyxy.tolist()  # Bounding boxes
        classes = r.boxes.cls.tolist()  # Class indices
        for box, cls in zip(boxes, classes):
            if cls == 0:  # Assuming 'person' is class 0 
                x1, y1, x2, y2 = map(int, box) 
                break  # Assuming only one person per image 

    # Square Cropping 
    center_x = (x1 + x2) // 2
    center_y = (y1 + y2) // 2
    crop_size = max(x2 - x1, y2 - y1)  # Size of the larger side

    crop_x1 = max(0, center_x - crop_size // 2)
    crop_y1 = max(0, center_y - crop_size // 2)
    crop_x2 = min(img.shape[1], crop_x1 + crop_size)
    crop_y2 = min(img.shape[0], crop_y1 + crop_size)

    cropped_img = img[crop_y1:crop_y2, crop_x1:crop_x2]

    # Resize cropped image to desired size
    cropped_img = cv2.resize(cropped_img, img_size)
    # Preprocess for VGG16
    cropped_img = image.img_to_array(cropped_img) 
    cropped_img = preprocess_input(cropped_img)
    cropped_img = np.expand_dims(cropped_img, axis=0) 

    # Load VGG16 model (without top)
    features = base_model.predict(cropped_img)
    features = features.reshape(features.shape[0], -1) 
    # features = scaler.transform(features)

    prediction = model.predict(features)[0]  
    predicted_class = class_names[prediction] 

    return predicted_class

new_image_path = 'uploads/bored2.jpg' # Replace with your image path
predicted_class = predict_image(new_image_path, lr_model, class_names)
print("Predicted Class:", predicted_class)
# Out:
# 0: 384x640 1 person, 858.1ms
# Speed: 2.0ms preprocess, 858.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# Predicted Class: fatigue

# %% [markdown]
# I tried all the possible ways that i could thing of to have a good accuracy of the model, and making sure that the model is performing well on unseen data, but I always fell into overfitting again. In this notebook I found out that even when I had overfitting, I noticed that logistic regression model and svm model are actually smart and perform well across majority of labels except for "using phone" and "raising hand".

# %%
joblib.dump(model, "svm_3.pkl") # kinda good
joblib.dump(knn_model, "knn_3.pkl") #dumb
joblib.dump(dt_model, "dt_3.pkl") # Very stupid
joblib.dump(lr_model, "lr_3.pkl") # good to be fair
joblib.dump(rf_model, "rf_3.pkl") # bad
# Out:
# ['rf_3.pkl']
